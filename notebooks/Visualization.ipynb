# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199


json = pd.read_json("./output.json")

json.head()
# Out:
# <ipython-input-17-8d84fc1c6dbe>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)  # or 199
#                                                   headline  likes  comments  \
# 0  5 Tipps für gute Auftritte in Videokonferenzen           0      0
# 1  Wo KI wirklich Sinn macht                                0      0
# 2  Das sind die Sieger:innen des DIGITAL LEADER AWARD 2020  1      0
# 3  Eine Software für 37 Millionen Versicherte               3      0
# 4  Sorgen Sie für einen IT-Vertrag auf Augenhöhe            16     1
#
#                                date
# 0  \n        Today\n
# 1  \n        Today\n
# 2  \n        Friday, 11 September\n
# 3  \n        Friday, 11 September\n
# 4  \n        Friday, 11 September\n

# %%
json.size
# Out:
# 8200

# %%
sorted = json.sort_values(by=["likes"], ascending=False)

# %%
json.plot(x = "headline", y="likes", kind="scatter")
# Out:
# <AxesSubplot:xlabel='headline', ylabel='likes'>

# %%
sorted.plot(x="headline", y="likes", kind="line")
# Out:
# /home/tarasowski/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='headline'>

# %%
sorted[:100]
# Out:
#                                                                           headline  \
# 1183  Die IT-Organisation ändert sich radikal
# 1128  Gescheitert am ERP-System
# 1068  Wie die IT-Organisation der Zukunft aussieht
# 1557  Gartner nennt 5 Megatrends bis 2029
# 1966  Digitalisierung ist keine Digitale Transformation
# 1948  Digitale Transformation ist kein IT-Projekt
# 1131  Uneinsichtige Projektverantwortliche: Zombie-IT-Projekte schaden Unternehmen
# 962   Der IT-Fachkräftemangel geht ins Geld
# 1004  SAP will Komplett-Dienstleister werden
# 1215  Schwarz-Gruppe will Cloud aufbauen
# 1683  Bis 2022 ist Plan-Build-Run abgeschafft
# 1140  Die wichtigsten Alternativen zur Gehaltserhöhung
# 1231  Lieber keinen neuen Mitarbeiter einstellen
# 1865  Die 6 Megatrends der Zukunft
# 267   140.000 Siemens-Mitarbeiter müssen nicht mehr täglich ins Büro
# 1875  Der Chief Digital Officer leistet noch Pionierarbeit
# 1505  Wie die Daimler-IT das Tempo verdoppelt
# ...

# %%
sorted["indexes"] = sorted["headline"].str.find("KI")

# %%
sorted.sort_values(by=["indexes"], ascending=False)
# Out:
#                                                                                     headline  \
# 1688  Mit sozialer, emotionaler Intelligenz das Potenzial von KI ausschöpfen
# 1472  Margrethe Vestager plant Regeln zur Entwicklung von KI
# 1960  Gartner sieht enormen wirtschaftlichen Hebel im KI-Einsatz
# 1188  MediaMarktSaturn verbessert Webshops mit KI
# 1093  Bosch bringt ab 2025 alle Produkte mit KI
# 1077  Forscher wollen "Desktop-Messies" mit KI helfen
# 1356  Landtechnik-Messe Agritechnica zeigt KI und Robotik auf dem Feld
# 1679  Bayern will führender Standort für KI werden
# 284   Siemens steigert Sicherheit mit KI und Analytics
# 260   Siemens steigert Sicherheit mit KI und Analytics
# 1210  Weltweit erste Universität für KI-Absolventen
# 706   Metro steuert Lieferkette mit KI
# 1493  Die wachsende Bedrohung durch KI
# 1007  Weltwirtschaftsforum zeigt KI-Ratgeber
# 1326  ING DiBa bindet Kunden mit KI
# 143   Bin ich schlau genug für KI?
# ...
